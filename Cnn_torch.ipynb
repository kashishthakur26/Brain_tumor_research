# %%
import torch

# Check if CUDA (GPU) is available
if torch.cuda.is_available():
    print("CUDA is available. PyTorch can use the GPU.")
    print("Number of available GPUs:", torch.cuda.device_count())
    print("Current GPU device:", torch.cuda.current_device())
    print("GPU Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print("CUDA is not available. PyTorch will use the CPU.")
# Out:
# CUDA is available. PyTorch can use the GPU.
# Number of available GPUs: 1
# Current GPU device: 0
# GPU Name: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.transforms import transforms
import torch.optim as optim
# utils
import os
from glob import glob
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
# visualization
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix

# %%
dataset_path = "C:/Users/91623/Desktop/Brain_tumor_research/Data"
train_path = "C:/Users/91623/Desktop/Brain_tumor_research/Data/Training"
test_path = "C:/Users/91623/Desktop/Brain_tumor_research/Data/Testing"
image_size = (256,256)
num_classes = 4
train_paths = glob(f"{train_path}/*/*.jpg")
test_paths = glob(f"{test_path}/*/*.jpg")

# %%
image_size = (224,224)
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(10),
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class dataset(Dataset):
    def __init__(self,paths,transform=None):
        self.paths = paths
        self.transform = transform
        self.labels = [self.get_label(path) for path in self.paths]
        self.labels_to_index = {label:index for index,label in enumerate(list(set(self.labels)))}
    
    def __getitem__(self,index):
        img_path = self.paths[index]
        img = Image.open(img_path).convert('RGB') 
        label = self.labels[index]
        label_index = self.labels_to_index[label]
        
        if self.transform:
            img = self.transform(img)
        
        return img, label_index,label
    
    
    def __len__(self):
        return len(self.paths)
    
    
    def get_label(self, path):
        return os.path.basename(os.path.dirname(path))

# %%
train_dataset = dataset(train_paths, transform=train_transform)
test_dataset = dataset(test_paths, transform=test_transform)

# %%
val_dataset, test_dataset = train_test_split(test_dataset,test_size=0.5, random_state=ord("H"))

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# display sample images with classes
train_iter = iter(train_loader)
images, labels_indices, labels = next(train_iter)

def imshow(input_images, labels_indices,labels):
    label_dict = {"notumor":"No Tumor", "glioma":"Glioma", "meningioma":"Meningioma","pituitary":"Pituitary"}
    input_images=input_images.numpy().transpose((0,2, 3, 1))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input_images = std * input_images + mean
    input_images = np.clip(input_images, 0, 1)
    fig, axes = plt.subplots(8, 4, figsize=(8, 16))
    for i, ax in enumerate(axes.flat):
        ax.imshow(input_images[i])
        ax.axis('off')
        ax.set_title(label_dict[labels[i]], fontsize=12)
    plt.tight_layout()
    plt.show()


imshow(images, labels_indices,labels)

# %%
dataiter = iter(train_loader)
batch = next(dataiter)
print(len(batch))
# Out:
# 3

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel,self).__init__()
        
        self.conv1 = nn.Conv2d(3,32,kernel_size=4,stride=1,padding=0)
        self.bn1 = nn.BatchNorm2d(32)
        
        self.conv2 = nn.Conv2d(32,64,kernel_size=4,stride=1,padding=0)
        self.bn2 = nn.BatchNorm2d(64)
        
        self.conv3 = nn.Conv2d(64,128,kernel_size=4,stride=1,padding=0)
        self.bn3 = nn.BatchNorm2d(128)
        
        self.conv4 = nn.Conv2d(128,128,kernel_size=4,stride=1,padding=0)
        self.bn4 = nn.BatchNorm2d(128)
    

        self.pool = nn.MaxPool2d(kernel_size=3, stride=3)
        self.pool2= nn.MaxPool2d(kernel_size=3, stride=2)
        
        self.fc1 = nn.Linear(6*6*128,512)
        self.fc2 = nn.Linear(512,num_classes)
        
        self.flatten = nn.Flatten()
        self.relu = nn.ReLU() 
        self.dropout = nn.Dropout(0.5)
        
        
        
    def forward(self,x):
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        x = self.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = self.relu(self.bn3(self.conv3(x)))
        x = self.pool2(x)
        x = self.relu(self.bn4(self.conv4(x)))
        x = self.flatten(x)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
model = CNNModel().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr=0.0001)

# %%
def train_epoch():
    model.train()
    total_loss = 0.0 
    total_correct = 0
    total_predictions = 0
    
    for batch_number, (images, labels_indices, labels) in enumerate(train_loader):
        images, labels_indices = images.to(device), labels_indices.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(images)
        loss = criterion(outputs, labels_indices)
        total_loss += loss.item()
        
        # Calculate accuracy
        _, predicted = torch.max(outputs, 1)
        total_predictions += labels_indices.size(0)
        total_correct += (predicted == labels_indices).sum().item()
        
        loss.backward()
        optimizer.step()
        
        if (batch_number and batch_number % 150 == 0):
            c_loss = total_loss / (batch_number + 1)
            accuracy = total_correct / total_predictions
            print(f"Batch {batch_number}/{len(train_loader)}, Loss: {c_loss:0.4f}, Accuracy: {accuracy * 100:.2f}%")
    
    avg_loss = total_loss / len(train_loader)
    avg_accuracy = total_correct / total_predictions
    
    return avg_loss, avg_accuracy

# %%
def eval_model():
    model.eval()
    total_loss = 0.0 
    total_correct = 0
    total_predictions = 0
    
    with torch.no_grad():
        for batch_number, (images, labels_indices, labels) in enumerate(val_loader):
            images, labels_indices = images.to(device), labels_indices.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels_indices)
            total_loss += loss.item()
            
            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total_predictions += labels_indices.size(0)
            total_correct += (predicted == labels_indices).sum().item()
            
    avg_loss = total_loss / len(val_loader)
    avg_accuracy = total_correct / total_predictions
    
    return avg_loss, avg_accuracy

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# %%
best_score = float("inf")
n_epochs = 40
tolerance = 0

for epoch in range(n_epochs):
    print(f"Epoch {epoch},   ", end="")
    avg_train_loss, train_accuracy = train_epoch()
    avg_eval_loss, eval_accuracy = eval_model()
    
    if avg_eval_loss < best_score:
        best_score = avg_eval_loss
        torch.save(model.state_dict(), f"model_{epoch+1}")
        tolerance = 0
    else:
        tolerance += 1
        if tolerance >= 8:
            break
            
    train_losses.append(avg_train_loss)
    val_losses.append(avg_eval_loss)
    train_accuracies.append(train_accuracy)
    val_accuracies.append(eval_accuracy)
    
    print(f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy * 100:.2f}%")
    print(f"Eval Loss: {avg_eval_loss:.4f}, Eval Accuracy: {eval_accuracy * 100:.2f}%")
# Out:
# Epoch 0,   Batch 150/179, Loss: 0.6061, Accuracy: 77.13%
# Train Loss: 0.5823, Train Accuracy: 78.05%
# Eval Loss: 0.6022, Eval Accuracy: 78.17%
# Epoch 1,   Batch 150/179, Loss: 0.3560, Accuracy: 86.92%
# Train Loss: 0.3559, Train Accuracy: 87.06%
# Eval Loss: 0.3778, Eval Accuracy: 84.73%
# Epoch 2,   Batch 150/179, Loss: 0.2965, Accuracy: 88.56%
# Train Loss: 0.2969, Train Accuracy: 88.46%
# Eval Loss: 0.3782, Eval Accuracy: 86.11%
# Epoch 3,   Batch 150/179, Loss: 0.2543, Accuracy: 90.19%
# Train Loss: 0.2545, Train Accuracy: 90.41%
# Eval Loss: 0.3170, Eval Accuracy: 87.18%
# Epoch 4,   Batch 150/179, Loss: 0.2201, Accuracy: 92.20%
# Train Loss: 0.2224, Train Accuracy: 92.10%
# Eval Loss: 0.2190, Eval Accuracy: 93.13%
# Epoch 5,   Batch 150/179, Loss: 0.1896, Accuracy: 93.17%
# Train Loss: 0.1883, Train Accuracy: 93.21%
# Eval Loss: 0.2634, Eval Accuracy: 90.23%
# Epoch 6,   Batch 150/179, Loss: 0.1673, Accuracy: 94.18%
# Train Loss: 0.1688, Train Accuracy: 94.15%
# Eval Loss: 0.2581, Eval Accuracy: 90.53%
# Epoch 7,   Batch 150/179, Loss: 0.1599, Accuracy: 94.18%
# Train Loss: 0.1591, Train Accuracy: 94.19%
# Eval Loss: 0.2176, Eval Accuracy: 92.37%
# Epoch 8,   Batch 150/179, Loss: 0.1449, Accuracy: 94.70%
# Train Loss: 0.1429, Train Accuracy: 94.91%
# Eval Loss: 0.1935, Eval Accuracy: 92.67%
# Epoch 9,   Batch 150/179, Loss: 0.1285, Accuracy: 95.72%
# Train Loss: 0.1269, Train Accuracy: 95.62%
# Eval Loss: 0.1652, Eval Accuracy: 93.89%
# Epoch 10,   Batch 150/179, Loss: 0.1108, Accuracy: 96.11%
# Train Loss: 0.1127, Train Accuracy: 95.97%
# Eval Loss: 0.1715, Eval Accuracy: 93.13%
# Epoch 11,   Batch 150/179, Loss: 0.1118, Accuracy: 96.25%
# Train Loss: 0.1068, Train Accuracy: 96.31%
# Eval Loss: 0.1305, Eval Accuracy: 95.11%
# Epoch 12,   Batch 150/179, Loss: 0.0979, Accuracy: 96.44%
# Train Loss: 0.0975, Train Accuracy: 96.36%
# Eval Loss: 0.1077, Eval Accuracy: 96.49%
# Epoch 13,   Batch 150/179, Loss: 0.0961, Accuracy: 96.71%
# Train Loss: 0.0927, Train Accuracy: 96.87%
# Eval Loss: 0.1021, Eval Accuracy: 96.95%
# Epoch 14,   Batch 150/179, Loss: 0.0847, Accuracy: 97.00%
# Train Loss: 0.0854, Train Accuracy: 96.97%
# Eval Loss: 0.0832, Eval Accuracy: 96.79%
# Epoch 15,   Batch 150/179, Loss: 0.0807, Accuracy: 97.19%
# Train Loss: 0.0829, Train Accuracy: 97.20%
# Eval Loss: 0.1329, Eval Accuracy: 94.96%
# Epoch 16,   Batch 150/179, Loss: 0.0850, Accuracy: 96.75%
# Train Loss: 0.0852, Train Accuracy: 96.83%
# Eval Loss: 0.1072, Eval Accuracy: 95.88%
# Epoch 17,   Batch 150/179, Loss: 0.0626, Accuracy: 97.81%
# Train Loss: 0.0655, Train Accuracy: 97.76%
# Eval Loss: 0.0674, Eval Accuracy: 98.02%
# Epoch 18,   Batch 150/179, Loss: 0.0673, Accuracy: 97.83%
# Train Loss: 0.0664, Train Accuracy: 97.83%
# Eval Loss: 0.0758, Eval Accuracy: 97.56%
# Epoch 19,   Batch 150/179, Loss: 0.0585, Accuracy: 97.91%
# Train Loss: 0.0611, Train Accuracy: 97.81%
# Eval Loss: 0.1944, Eval Accuracy: 92.82%
# Epoch 20,   Batch 150/179, Loss: 0.0590, Accuracy: 97.76%
# Train Loss: 0.0554, Train Accuracy: 97.92%
# Eval Loss: 0.0795, Eval Accuracy: 97.56%
# Epoch 21,   Batch 150/179, Loss: 0.0620, Accuracy: 97.81%
# Train Loss: 0.0634, Train Accuracy: 97.76%
# Eval Loss: 0.0619, Eval Accuracy: 97.86%
# Epoch 22,   Batch 150/179, Loss: 0.0595, Accuracy: 97.81%
# Train Loss: 0.0615, Train Accuracy: 97.76%
# Eval Loss: 0.0750, Eval Accuracy: 96.95%
# Epoch 23,   Batch 150/179, Loss: 0.0586, Accuracy: 97.70%
# Train Loss: 0.0587, Train Accuracy: 97.78%
# Eval Loss: 0.0393, Eval Accuracy: 98.93%
# Epoch 24,   Batch 150/179, Loss: 0.0477, Accuracy: 98.34%
# Train Loss: 0.0506, Train Accuracy: 98.28%
# Eval Loss: 0.0763, Eval Accuracy: 96.95%
# Epoch 25,   Batch 150/179, Loss: 0.0513, Accuracy: 98.39%
# Train Loss: 0.0519, Train Accuracy: 98.35%
# Eval Loss: 0.0752, Eval Accuracy: 96.79%
# Epoch 26,   Batch 150/179, Loss: 0.0507, Accuracy: 98.24%
# Train Loss: 0.0483, Train Accuracy: 98.32%
# Eval Loss: 0.0349, Eval Accuracy: 98.93%
# Epoch 27,   Batch 150/179, Loss: 0.0327, Accuracy: 98.78%
# Train Loss: 0.0338, Train Accuracy: 98.72%
# Eval Loss: 0.0548, Eval Accuracy: 98.02%
# Epoch 28,   Batch 150/179, Loss: 0.0431, Accuracy: 98.49%
# Train Loss: 0.0472, Train Accuracy: 98.37%
# Eval Loss: 0.0640, Eval Accuracy: 97.71%
# Epoch 29,   Batch 150/179, Loss: 0.0470, Accuracy: 98.41%
# Train Loss: 0.0452, Train Accuracy: 98.48%
# Eval Loss: 0.0388, Eval Accuracy: 98.78%
# Epoch 30,   Batch 150/179, Loss: 0.0331, Accuracy: 99.01%
# Train Loss: 0.0388, Train Accuracy: 98.69%
# Eval Loss: 0.0724, Eval Accuracy: 97.56%
# Epoch 31,   Batch 150/179, Loss: 0.0412, Accuracy: 98.53%
# Train Loss: 0.0411, Train Accuracy: 98.51%
# Eval Loss: 0.0896, Eval Accuracy: 97.10%
# Epoch 32,   Batch 150/179, Loss: 0.0414, Accuracy: 98.61%
# Train Loss: 0.0431, Train Accuracy: 98.56%
# Eval Loss: 0.0480, Eval Accuracy: 98.02%
# Epoch 33,   Batch 150/179, Loss: 0.0429, Accuracy: 98.57%
# Train Loss: 0.0412, Train Accuracy: 98.60%
# Eval Loss: 0.0347, Eval Accuracy: 99.08%
# Epoch 34,   Batch 150/179, Loss: 0.0329, Accuracy: 98.78%
# Train Loss: 0.0332, Train Accuracy: 98.79%
# Eval Loss: 0.0646, Eval Accuracy: 97.40%
# Epoch 35,   Batch 150/179, Loss: 0.0272, Accuracy: 99.05%
# Train Loss: 0.0301, Train Accuracy: 98.90%
# Eval Loss: 0.0608, Eval Accuracy: 97.86%
# Epoch 36,   Batch 150/179, Loss: 0.0504, Accuracy: 98.41%
# Train Loss: 0.0471, Train Accuracy: 98.53%
# Eval Loss: 0.0577, Eval Accuracy: 98.17%
# Epoch 37,   Batch 150/179, Loss: 0.0366, Accuracy: 98.68%
# Train Loss: 0.0365, Train Accuracy: 98.63%
# Eval Loss: 0.0414, Eval Accuracy: 98.78%
# Epoch 38,   Batch 150/179, Loss: 0.0249, Accuracy: 99.23%
# Train Loss: 0.0233, Train Accuracy: 99.25%
# Eval Loss: 0.0538, Eval Accuracy: 98.17%
# Epoch 39,   Batch 150/179, Loss: 0.0330, Accuracy: 99.05%
# Train Loss: 0.0322, Train Accuracy: 99.02%
# Eval Loss: 0.0589, Eval Accuracy: 97.71%

# %%
import matplotlib.pyplot as plt

# Plotting loss history
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss History')
plt.tight_layout()
plt.show()

# Plotting accuracy history
plt.figure(figsize=(12, 6))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy History')
plt.tight_layout()
plt.show()

# %%
models = glob("C:/Users/91623/Desktop/Brain_tumor_research/*")
model_num = [int(i.split("_")[-1]) for i in models if i.split("_")[-1].isdigit()]
best_model_path = "C:/Users/91623/Desktop/Brain_tumor_research/model_" +str(sorted(model_num)[-1])
best_model_path
# Out:
# 'C:/Users/91623/Desktop/Brain_tumor_research/model_34'

# %%
best_model = CNNModel().to(device)

best_model.load_state_dict(torch.load(best_model_path, map_location=device))
# Out:
# <All keys matched successfully>

# %%
def predict(
    model:nn.Module, 
    sample_loader:torch.utils.data.DataLoader,
    device:torch.device) -> np.ndarray:
    model.eval()
    predictions = []
    with torch.inference_mode():
        for batch, (X, y,labels) in enumerate(sample_loader):
            X, y = X.to(device), y.to(device)
            y_pred = model(X) 
            predictions.append(y_pred.cpu().numpy())
        
    return np.vstack(predictions)

# %%
best_model_props = predict(best_model, test_loader, device)
best_model_preds = np.argmax(best_model_props, axis=1)
best_model_preds.shape[0]
# Out:
# 656

# %%
gen_labels_test_set = [label[1] for label in test_dataset]
len(gen_labels_test_set)
# Out:
# 656

# %%
print(f"Best Model Test Accuracy: {round(accuracy_score(gen_labels_test_set,best_model_preds)*100,2)}%")
# Out:
# Best Model Test Accuracy: 98.48%

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
cm = confusion_matrix(gen_labels_test_set, best_model_preds)
precision = precision_score(gen_labels_test_set, best_model_preds, average='weighted')
recall = recall_score(gen_labels_test_set, best_model_preds, average='weighted')
f1 = f1_score(gen_labels_test_set, best_model_preds, average='weighted')
labels = set([label[2] for label in test_dataset])
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label', labelpad=20, fontsize=14)
plt.ylabel('Truth Label', labelpad=20, fontsize=14)
plt.show()
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Precision: 0.9848523624313065
# Recall: 0.9847560975609756
# F1 Score: 0.9846854915049665

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
# Calculate confusion matrix
cm = confusion_matrix(gen_labels_test_set, best_model_preds)

# Extract unique labels (class names)
labels = sorted(set(gen_labels_test_set))
# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label', labelpad=20, fontsize=14)
plt.ylabel('Truth Label', labelpad=20, fontsize=14)
plt.show()
# Calculate precision, recall, and F1 score for each class
precision_per_class = precision_score(gen_labels_test_set, best_model_preds, average=None)
recall_per_class = recall_score(gen_labels_test_set, best_model_preds, average=None)
f1_per_class = f1_score(gen_labels_test_set, best_model_preds, average=None)

# Print metrics for each class
for i, label in enumerate(labels):
    print(f'Class: {label}')
    print(f'  Precision: {precision_per_class[i]}')
    print(f'  Recall: {recall_per_class[i]}')
    print(f'  F1 Score: {f1_per_class[i]}')
# Out:
# Class: 0
#   Precision: 0.9932885906040269
#   Recall: 0.9548387096774194
#   F1 Score: 0.9736842105263158
# Class: 1
#   Precision: 0.9852216748768473
#   Recall: 1.0
#   F1 Score: 0.9925558312655087
# Class: 2
#   Precision: 0.9803921568627451
#   Recall: 0.9933774834437086
#   F1 Score: 0.9868421052631579
# Class: 3
#   Precision: 0.9801324503311258
#   Recall: 0.9866666666666667
#   F1 Score: 0.9833887043189369
