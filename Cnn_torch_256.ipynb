# %%
import torch

# Check if CUDA (GPU) is available
if torch.cuda.is_available():
    print("CUDA is available. PyTorch can use the GPU.")
    print("Number of available GPUs:", torch.cuda.device_count())
    print("Current GPU device:", torch.cuda.current_device())
    print("GPU Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print("CUDA is not available. PyTorch will use the CPU.")
# Out:
# CUDA is available. PyTorch can use the GPU.
# Number of available GPUs: 1
# Current GPU device: 0
# GPU Name: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
import torch

# Before starting the training loop
torch.cuda.empty_cache()

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.transforms import transforms
import torch.optim as optim
import os
from glob import glob
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix

# %%
dataset_path = "C:/Users/91623/Desktop/Brain_tumor_research/Data"
train_path = "C:/Users/91623/Desktop/Brain_tumor_research/Data/Training"
test_path = "C:/Users/91623/Desktop/Brain_tumor_research/Data/Testing"
image_size = (256,256)
num_classes = 4
train_paths = glob(f"{train_path}/*/*.jpg")
test_paths = glob(f"{test_path}/*/*.jpg")

# %%
image_size = (256,256)
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(10),
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class dataset(Dataset):
    def __init__(self,paths,transform=None):
        self.paths = paths
        self.transform = transform
        self.labels = [self.get_label(path) for path in self.paths]
        self.labels_to_index = {label:index for index,label in enumerate(list(set(self.labels)))}
    
    def __getitem__(self,index):
        img_path = self.paths[index]
        img = Image.open(img_path).convert('RGB') 
        label = self.labels[index]
        label_index = self.labels_to_index[label]
        
        if self.transform:
            img = self.transform(img)
        
        return img, label_index,label
    
    
    def __len__(self):
        return len(self.paths)
    
    
    def get_label(self, path):
        return os.path.basename(os.path.dirname(path))

# %%
train_dataset = dataset(train_paths, transform=train_transform)
test_dataset = dataset(test_paths, transform=test_transform)

# %%
val_dataset, test_dataset = train_test_split(test_dataset,test_size=0.5, random_state=ord("H"))

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
train_iter = iter(train_loader)
images, labels_indices, labels = next(train_iter)

def imshow(input_images, labels_indices,labels):
    label_dict = {"notumor":"No Tumor", "glioma":"Glioma", "meningioma":"Meningioma","pituitary":"Pituitary"}
    input_images=input_images.numpy().transpose((0,2, 3, 1))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input_images = std * input_images + mean
    input_images = np.clip(input_images, 0, 1)
    fig, axes = plt.subplots(8, 4, figsize=(8, 16))
    for i, ax in enumerate(axes.flat):
        ax.imshow(input_images[i])
        ax.axis('off')
        ax.set_title(label_dict[labels[i]], fontsize=12)
    plt.tight_layout()
    plt.show()


imshow(images, labels_indices,labels)

# %%
dataiter = iter(train_loader)
batch = next(dataiter)
print(len(batch))
# Out:
# 3

# %%
import torch
import torch.nn as nn
import os

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.bn4 = nn.BatchNorm2d(128)
        
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # After 4 conv/pool layers with input size 256x256
        # Output will be (256/2/2/2/2) = 16x16 with 128 channels
        self.fc1 = nn.Linear(16 * 16 * 128, 512)
        self.fc2 = nn.Linear(512, 4) 
        
        self.flatten = nn.Flatten()
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        
    def forward(self, x):
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        x = self.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = self.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)
        x = self.relu(self.bn4(self.conv4(x)))
        x = self.pool(x)
        x = self.flatten(x)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

model = CNNModel().to(device)
print(model)
# Out:
# CNNModel(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=32768, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=4, bias=True)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
model = CNNModel().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr=0.0001)

# %%
def train_epoch():
    model.train()
    total_loss = 0.0 
    total_correct = 0
    total_predictions = 0
    
    for batch_number, (images, labels_indices, labels) in enumerate(train_loader):
        images, labels_indices = images.to(device), labels_indices.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(images)
        loss = criterion(outputs, labels_indices)
        total_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total_predictions += labels_indices.size(0)
        total_correct += (predicted == labels_indices).sum().item()
        
        loss.backward()
        optimizer.step()
        
        if (batch_number and batch_number % 150 == 0):
            c_loss = total_loss / (batch_number + 1)
            accuracy = total_correct / total_predictions
            print(f"Batch {batch_number}/{len(train_loader)}, Loss: {c_loss:0.4f}, Accuracy: {accuracy * 100:.2f}%")
    
    avg_loss = total_loss / len(train_loader)
    avg_accuracy = total_correct / total_predictions
    
    return avg_loss, avg_accuracy

# %%
def eval_model():
    model.eval()
    total_loss = 0.0 
    total_correct = 0
    total_predictions = 0
    
    with torch.no_grad():
        for batch_number, (images, labels_indices, labels) in enumerate(val_loader):
            images, labels_indices = images.to(device), labels_indices.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels_indices)
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_predictions += labels_indices.size(0)
            total_correct += (predicted == labels_indices).sum().item()
            
    avg_loss = total_loss / len(val_loader)
    avg_accuracy = total_correct / total_predictions
    
    return avg_loss, avg_accuracy

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# %%
best_score = float("inf")
n_epochs = 40
tolerance = 0

for epoch in range(n_epochs):
    print(f"Epoch {epoch},   ", end="")
    avg_train_loss, train_accuracy = train_epoch()
    avg_eval_loss, eval_accuracy = eval_model()
    
    if avg_eval_loss < best_score:
        best_score = avg_eval_loss
        torch.save(model.state_dict(), f"model_{epoch+1}")
        tolerance = 0
    else:
        tolerance += 1
        if tolerance >= 8:
            break
            
    train_losses.append(avg_train_loss)
    val_losses.append(avg_eval_loss)
    train_accuracies.append(train_accuracy)
    val_accuracies.append(eval_accuracy)
    
    print(f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy * 100:.2f}%")
    print(f"Eval Loss: {avg_eval_loss:.4f}, Eval Accuracy: {eval_accuracy * 100:.2f}%")
# Out:
# Epoch 0,   Batch 150/179, Loss: 0.7938, Accuracy: 69.41%
# Train Loss: 0.7656, Train Accuracy: 70.52%
# Eval Loss: 0.5716, Eval Accuracy: 78.02%
# Epoch 1,   Batch 150/179, Loss: 0.5084, Accuracy: 80.82%
# Train Loss: 0.5100, Train Accuracy: 80.65%
# Eval Loss: 0.4516, Eval Accuracy: 79.69%
# Epoch 2,   Batch 150/179, Loss: 0.4320, Accuracy: 83.73%
# Train Loss: 0.4289, Train Accuracy: 83.72%
# Eval Loss: 0.4307, Eval Accuracy: 82.44%
# Epoch 3,   Batch 150/179, Loss: 0.3811, Accuracy: 85.91%
# Train Loss: 0.3795, Train Accuracy: 85.94%
# Eval Loss: 0.3236, Eval Accuracy: 86.41%
# Epoch 4,   Batch 150/179, Loss: 0.3371, Accuracy: 87.36%
# Train Loss: 0.3338, Train Accuracy: 87.46%
# Eval Loss: 0.2980, Eval Accuracy: 87.63%
# Epoch 5,   Batch 150/179, Loss: 0.3070, Accuracy: 88.56%
# Train Loss: 0.2998, Train Accuracy: 88.66%
# Eval Loss: 0.2865, Eval Accuracy: 87.94%
# Epoch 6,   Batch 150/179, Loss: 0.2707, Accuracy: 89.88%
# Train Loss: 0.2682, Train Accuracy: 90.00%
# Eval Loss: 0.2642, Eval Accuracy: 88.24%
# Epoch 7,   Batch 150/179, Loss: 0.2600, Accuracy: 90.48%
# Train Loss: 0.2567, Train Accuracy: 90.56%
# Eval Loss: 0.2371, Eval Accuracy: 90.08%
# Epoch 8,   Batch 150/179, Loss: 0.2494, Accuracy: 91.02%
# Train Loss: 0.2448, Train Accuracy: 91.11%
# Eval Loss: 0.2361, Eval Accuracy: 89.77%
# Epoch 9,   Batch 150/179, Loss: 0.2154, Accuracy: 92.09%
# Train Loss: 0.2178, Train Accuracy: 91.88%
# Eval Loss: 0.2593, Eval Accuracy: 89.47%
# Epoch 10,   Batch 150/179, Loss: 0.2093, Accuracy: 92.20%
# Train Loss: 0.2117, Train Accuracy: 92.05%
# Eval Loss: 0.1999, Eval Accuracy: 91.91%
# Epoch 11,   Batch 150/179, Loss: 0.2195, Accuracy: 91.93%
# Train Loss: 0.2148, Train Accuracy: 92.12%
# Eval Loss: 0.2059, Eval Accuracy: 91.45%
# Epoch 12,   Batch 150/179, Loss: 0.1935, Accuracy: 92.90%
# Train Loss: 0.1971, Train Accuracy: 92.65%
# Eval Loss: 0.1833, Eval Accuracy: 92.52%
# Epoch 13,   Batch 150/179, Loss: 0.2022, Accuracy: 92.49%
# Train Loss: 0.1999, Train Accuracy: 92.49%
# Eval Loss: 0.1698, Eval Accuracy: 92.82%
# Epoch 14,   Batch 150/179, Loss: 0.1858, Accuracy: 93.11%
# Train Loss: 0.1834, Train Accuracy: 93.15%
# Eval Loss: 0.2227, Eval Accuracy: 91.60%
# Epoch 15,   Batch 150/179, Loss: 0.1638, Accuracy: 93.79%
# Train Loss: 0.1645, Train Accuracy: 93.79%
# Eval Loss: 0.1627, Eval Accuracy: 93.13%
# Epoch 16,   Batch 150/179, Loss: 0.1607, Accuracy: 93.71%
# Train Loss: 0.1596, Train Accuracy: 93.87%
# Eval Loss: 0.1236, Eval Accuracy: 95.27%
# Epoch 17,   Batch 150/179, Loss: 0.1561, Accuracy: 94.25%
# Train Loss: 0.1602, Train Accuracy: 94.12%
# Eval Loss: 0.1222, Eval Accuracy: 95.73%
# Epoch 18,   Batch 150/179, Loss: 0.1482, Accuracy: 94.66%
# Train Loss: 0.1453, Train Accuracy: 94.73%
# Eval Loss: 0.1626, Eval Accuracy: 93.59%
# Epoch 19,   Batch 150/179, Loss: 0.1346, Accuracy: 94.95%
# Train Loss: 0.1364, Train Accuracy: 94.87%
# Eval Loss: 0.1094, Eval Accuracy: 95.73%
# Epoch 20,   Batch 150/179, Loss: 0.1445, Accuracy: 95.26%
# Train Loss: 0.1466, Train Accuracy: 95.06%
# Eval Loss: 0.1188, Eval Accuracy: 95.57%
# Epoch 21,   Batch 150/179, Loss: 0.1283, Accuracy: 95.28%
# Train Loss: 0.1306, Train Accuracy: 95.26%
# Eval Loss: 0.0981, Eval Accuracy: 96.03%
# Epoch 22,   Batch 150/179, Loss: 0.1210, Accuracy: 95.72%
# Train Loss: 0.1210, Train Accuracy: 95.64%
# Eval Loss: 0.1309, Eval Accuracy: 94.96%
# Epoch 23,   Batch 150/179, Loss: 0.1248, Accuracy: 95.53%
# Train Loss: 0.1244, Train Accuracy: 95.40%
# Eval Loss: 0.1114, Eval Accuracy: 95.73%
# Epoch 24,   Batch 150/179, Loss: 0.1298, Accuracy: 95.26%
# Train Loss: 0.1272, Train Accuracy: 95.34%
# Eval Loss: 0.0830, Eval Accuracy: 97.25%
# Epoch 25,   Batch 150/179, Loss: 0.1092, Accuracy: 95.65%
# Train Loss: 0.1109, Train Accuracy: 95.82%
# Eval Loss: 0.1156, Eval Accuracy: 95.88%
# Epoch 26,   Batch 150/179, Loss: 0.1155, Accuracy: 95.78%
# Train Loss: 0.1154, Train Accuracy: 95.82%
# Eval Loss: 0.0900, Eval Accuracy: 97.25%
# Epoch 27,   Batch 150/179, Loss: 0.1006, Accuracy: 96.40%
# Train Loss: 0.0991, Train Accuracy: 96.45%
# Eval Loss: 0.0627, Eval Accuracy: 98.17%
# Epoch 28,   Batch 150/179, Loss: 0.1120, Accuracy: 95.78%
# Train Loss: 0.1115, Train Accuracy: 95.83%
# Eval Loss: 0.1007, Eval Accuracy: 96.95%
# Epoch 29,   Batch 150/179, Loss: 0.1055, Accuracy: 96.25%
# Train Loss: 0.1061, Train Accuracy: 96.31%
# Eval Loss: 0.0904, Eval Accuracy: 96.49%
# Epoch 30,   Batch 150/179, Loss: 0.1004, Accuracy: 96.48%
# Train Loss: 0.1038, Train Accuracy: 96.20%
# Eval Loss: 0.0720, Eval Accuracy: 97.86%
# Epoch 31,   Batch 150/179, Loss: 0.0918, Accuracy: 96.79%
# Train Loss: 0.0925, Train Accuracy: 96.78%
# Eval Loss: 0.0756, Eval Accuracy: 97.56%
# Epoch 32,   Batch 150/179, Loss: 0.0875, Accuracy: 97.02%
# Train Loss: 0.0878, Train Accuracy: 96.99%
# Eval Loss: 0.0922, Eval Accuracy: 96.34%
# Epoch 33,   Batch 150/179, Loss: 0.0761, Accuracy: 97.81%
# Train Loss: 0.0744, Train Accuracy: 97.79%
# Eval Loss: 0.0634, Eval Accuracy: 97.86%
# Epoch 34,   Batch 150/179, Loss: 0.0758, Accuracy: 97.27%
# Train Loss: 0.0765, Train Accuracy: 97.29%
# Eval Loss: 0.0785, Eval Accuracy: 97.25%
# Epoch 35,   Batch 150/179, Loss: 0.0852, Accuracy: 96.85%
# Train Loss: 0.0889, Train Accuracy: 96.78%
# Eval Loss: 0.0573, Eval Accuracy: 98.78%
# Epoch 36,   Batch 150/179, Loss: 0.0848, Accuracy: 97.14%
# Train Loss: 0.0903, Train Accuracy: 96.83%
# Eval Loss: 0.1463, Eval Accuracy: 94.66%
# Epoch 37,   Batch 150/179, Loss: 0.0795, Accuracy: 97.10%
# Train Loss: 0.0792, Train Accuracy: 97.13%
# Eval Loss: 0.0722, Eval Accuracy: 97.71%
# Epoch 38,   Batch 150/179, Loss: 0.0765, Accuracy: 97.43%
# Train Loss: 0.0774, Train Accuracy: 97.44%
# Eval Loss: 0.0566, Eval Accuracy: 98.63%
# Epoch 39,   Batch 150/179, Loss: 0.0716, Accuracy: 97.43%
# Train Loss: 0.0733, Train Accuracy: 97.36%
# Eval Loss: 0.0680, Eval Accuracy: 97.71%

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss History')

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy History')

plt.tight_layout()
plt.show()

# %%
# models = glob("C:/Users/91623/Desktop/Brain_tumor_research/*")
# model_num = [int(i.split("_")[-1]) for i in models if i.split("_")[-1].isdigit()]
best_model_path = "C:/Users/91623/Desktop/Brain_tumor_research/model_39" 
best_model_path
# Out:
# 'C:/Users/91623/Desktop/Brain_tumor_research/model_39'

# %%
best_model = CNNModel().to(device)

best_model.load_state_dict(torch.load(best_model_path, map_location=device))
# Out:
# <All keys matched successfully>

# %%
def predict(
    model:nn.Module, 
    sample_loader:torch.utils.data.DataLoader,
    device:torch.device) -> np.ndarray:
    model.eval()
    predictions = []
    with torch.inference_mode():
        for batch, (X, y,labels) in enumerate(sample_loader):
            X, y = X.to(device), y.to(device)
            y_pred = model(X) 
            predictions.append(y_pred.cpu().numpy())
        
    return np.vstack(predictions)

# %%
best_model_props = predict(best_model, test_loader, device)
best_model_preds = np.argmax(best_model_props, axis=1)
best_model_preds.shape[0]
# Out:
# 656

# %%
gen_labels_test_set = [label[1] for label in test_dataset]
len(gen_labels_test_set)
# Out:
# 656

# %%
print(f"Best Model Test Accuracy: {round(accuracy_score(gen_labels_test_set,best_model_preds)*100,2)}%")
# Out:
# Best Model Test Accuracy: 97.41%

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
cm = confusion_matrix(gen_labels_test_set, best_model_preds)
precision = precision_score(gen_labels_test_set, best_model_preds, average='weighted')
recall = recall_score(gen_labels_test_set, best_model_preds, average='weighted')
f1 = f1_score(gen_labels_test_set, best_model_preds, average='weighted')
labels = set([label[2] for label in test_dataset])
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label', labelpad=20, fontsize=14)
plt.ylabel('Truth Label', labelpad=20, fontsize=14)
plt.show()
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Precision: 0.9745467256039553
# Recall: 0.9740853658536586
# F1 Score: 0.9740280109136937
